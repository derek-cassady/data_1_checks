# %%
# a statement that prints "hello world!
print ('Hello World')
# Out:
# Hello World

# %%
list_1 = ['Bacon', 'Eggs', 'Hashbrowns', 'Toast', 'Pancake']

# %%
print (list_1[2])
# Out:
# Hashbrowns

# %%
dict_1 = {'Bacon': float(2.95), 
            'Eggs': float(3.15), 
            'Hashbrowns': float(1.75), 
            'Toast': float(1.25), 
            'Pancake' : float(2.05)}

# %%
print ("$", dict_1['Eggs'])
# Out:
# $ 3.15

# %%
tuple_1 = ('Bippity', 'Boppity', [4952, 1709, 3], 'Boo')
print (tuple_1 [2])
# Out:
# [4952, 1709, 3]
